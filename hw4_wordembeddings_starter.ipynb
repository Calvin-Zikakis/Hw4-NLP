# %% [markdown]
# For this homework, make sure that you format your notbook nicely and cite all sources in the appropriate sections. Programmatically generate or embed any figures or graphs that you need.
#
# Names: Calvin Zikakis, Sarah Schwallier

# %% [markdown]
# Section 1: Word2Vec paper questions
# ---------------------------
#
#     1) Describe how a CBOW word embedding is generated.
#
#     2) What is a CBOW word embedding and how is it different than a skip-gram word embedding?
#
#     3) What is the task that the authors use to evaluate the generated word embeddings?
#
#     4) What are PCA and t-SNE? Why are these important to the task of training and interpreting word embeddings?

# %% [markdown]
# Sources Cited
# --------------------------
# Efficient Estimation of Word Representations in Vector Space by Tomas Mikolov, Kai Chen, Greg Corrado, and Jeffrey Dean: https://arxiv.org/pdf/1301.3781.pdf
# J. Schler, M. Koppel, S. Argamon and J. Pennebaker (2006). Effects of Age and Gender on Blogging in Proceedings of 2006 AAAI Spring Symposium on Computational Approaches for Analyzing Weblogs.
# SENTENCE ORDERING USING RECURRENT NEURAL NETWORKS by Lajanugen Logeswaran, Honglak Lee & Dragomir Radev
# Speech and Language Processing
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 2: Training your own word embeddings
# --------------------------------
#
# The spooky authors dataset consists of excerpts from authors of horror novels including Edgar Allan Poe, Mary Shelley, and HP Lovecraft. These excerpts each have a unique ID as well as a three letter tag describing which author wrote the excerpt. The data is split into a training set and a test set. The test set is lacking the three letter code which labels the author.
#
#
# We are using the The Blog Authorship Corpus for our secondary dataset. We decided on this dataset as it is comprised of 681,288 posts from 19,320 bloggers. We scanned through this database and pulled a small chunk of the total amount of posts. This was to reduce the overall size of the dataset to help with performance in training word embedding. This dataset will provide a data that is written with a style simular to normal human conversation simularly to the spooky authors dataset. This should help insure our generated sentences have a natural sound to them.

# %%
# import your libraries here
import numpy as np
import sklearn
from sklearn.manifold import TSNE
import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import csv
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-022d00f0dec2> in <module>
#       2 import numpy as np
#       3 import sklearn
# ----> 4 import keras
#       5 import matplotlib.pyplot as plt
#       6 import pandas
#
# ModuleNotFoundError: No module named 'keras'

# %%
# -----------------Secondary Dataset Formatting and Trimming-------------------
# This cell trims and fixes the secondary dataset to get the data in a workable style
import re
from csv import reader


def format_secondaryDataset(training_file_path, output_file, sentence_length):
    '''
    this function takes the dataset and splits it to sentences and stores those in a txt file

    training_file_path = filepath of blogposts.csv
    output_file = outputfile name (.txt)
    sentence_length = minimum length sentences to grab (value is how many words per sentences)
    '''

    
    with open(training_file_path) as file:
        sentences = file.readlines()
    #open file
    
    file.close()
    
    output = open(output_file, "w+")
    
    count = 0
    
    for line in reader(sentences):
        blog_post = line[6]
        #Line[6] contains the blog post
        
        if count >= 7:
        #skip the stuff in the beggining. It's unneeded
        
            sentences = blog_post.split(".")
            #split the post on the periods to extract individual sentences
            
            for sentence in sentences:
            #loop over our list of sentences
            
                if sentence != "":
                #some blog posts contain '...'. This creates empty sentences. We don't want empty sentences
                    
                    #lets clean the sentence of symbols and make it all lowercase
                    
                    res = re.sub(' +', ' ', sentence)
                    res.strip('\t')
                    res.strip('\n')
                    #strip tabs and newlines
                    
                    lower = res.lower()
                    #make all lower case

                    whitelist = set('abcdefghijklmnopqrstuvwxyz 1234567890')
                    no_numbers_punct = ''.join(filter(whitelist.__contains__, lower))
                    #gets rid of punctuation

                    cleaned = no_numbers_punct.split()
                    
                    black_list = ['urllink']
                    #allows us to remove all 'urlLink' occurances
                    
                    if len(cleaned) >= sentence_length:
                        #adjust 4 if you only want longer sentences
                        #we are only concerned with sentences longer than 4 words
                        output.write(" ".join([i for i in cleaned if i not in black_list]) + "\n")
                    
                    
        if count == 2000:
        #Do not need this full dataset... It's 800mb's
            break
        
        count += 1
        

format_secondaryDataset("blogtext.csv", "secondaryDataset.txt", 5)

# %%
# code to train your word embeddings
from csv import reader
from gensim.models import Word2Vec


# -----------------Primary Dataset-------------------
def Clean_data_primary_dataset(training_file_path):
    #This function tokenizes the primary dataset and returns a cleaned version where each word making up a sentence is a nested list inside a larger list of the corpus
    output_list = []

    with open(training_file_path) as file:
        sentences = file.readlines()
    #open file
    file.close()
    
    count = 0
        
    for line in reader(sentences):
        
        if count != 0:
        #don't want first sentence

            sentence = line[1]
            
            lower = sentence.lower()
            #make all lower case

            whitelist = set('abcdefghijklmnopqrstuvwxyz 1234567890')
            no_numbers_punct = ''.join(filter(whitelist.__contains__, lower))
            #gets rid of punctuation

            cleaned = no_numbers_punct.split()
            
            output_list.append(cleaned)
            
        count += 1

    return output_list

    
sentences_primaryDataset = Clean_data_primary_dataset("train.csv")
#imports and cleans dataset

model_primaryDataset = Word2Vec(sentences_primaryDataset, min_count=1)
#creates word2vec model

print(model_primaryDataset)
#model summary

words_primaryDataset = list(model_primaryDataset.wv.vocab)
print(words_primaryDataset)
#shows the vocab

print(model_primaryDataset['sentence'])
#our model

# -----------------Secondary Dataset-------------------

#secondary dataset is stored as 'secondaryDataset.txt' after processing it

def tokenize_secondary_dataset(training_file_path):
    #tokenizes the secondary dataset and returns a cleaned version where each word making up a sentence is a nested list inside a larger list of the corpus
    
    output_list = []

    with open(training_file_path) as file:
        sentences = file.readlines()
        
    #open file
    file.close()
    
    for sentence in sentences:
    #loop over sentences
    
        words = sentence.split()
        #split sentences on the words
        
        output_list.append(words)
        #append words list to final output
    
    return output_list


sentences_secondaryDataset = tokenize_secondary_dataset("secondaryDataset.txt")
#secondary sentences

model_secondaryDataset = Word2Vec(sentences_secondaryDataset, min_count=1)
#creates word2vec model

print(model_secondaryDataset)
#model summary

words_secondaryDataset = list(model_secondaryDataset.wv.vocab)
print(words_secondaryDataset)
#shows the vocab

print(model_secondaryDataset['sentence'])
#our model
# Out:
# Word2Vec(vocab=25404, size=100, alpha=0.025)
# ['this', 'process', 'however', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'my', 'dungeon', 'as', 'i', 'might', 'make', 'its', 'circuit', 'and', 'return', 'to', 'point', 'whence', 'set', 'out', 'without', 'being', 'aware', 'fact', 'so', 'perfectly', 'uniform', 'seemed', 'wall', 'it', 'never', 'once', 'occurred', 'that', 'fumbling', 'be', 'a', 'mere', 'mistake', 'in', 'his', 'left', 'hand', 'was', 'gold', 'snuff', 'box', 'from', 'which', 'he', 'capered', 'down', 'hill', 'cutting', 'all', 'manner', 'fantastic', 'steps', 'took', 'incessantly', 'with', 'an', 'air', 'greatest', 'possible', 'self', 'satisfaction', 'how', 'lovely', 'is', 'spring', 'we', 'looked', 'windsor', 'terrace', 'on', 'sixteen', 'fertile', 'counties', 'spread', 'beneath', 'speckled', 'by', 'happy', 'cottages', 'wealthier', 'towns', 'former', 'years', 'heart', 'cheering', 'fair', 'finding', 'nothing', 'else', 'not', 'even', 'superintendent', 'abandoned', 'attempts', 'but', 'perplexed', 'look', 'occasionally', 'steals', 'over', 'countenance', 'sits', 'thinking', 'at', 'desk', 'youth', 'passed', 'solitude', 'best', 'spent', 'under', 'your', 'gentle', 'feminine', 'fosterage', 'has', 'refined', 'groundwork', 'character', 'cannot', 'overcome', 'intense', 'distaste', 'usual', 'brutality', 'exercised', 'board', 'ship', 'have', 'believed', 'necessary', 'when', 'heard', 'mariner', 'equally', 'noted', 'for', 'kindliness', 'respect', 'obedience', 'paid', 'him', 'crew', 'felt', 'myself', 'peculiarly', 'fortunate', 'able', 'secure', 'services', 'astronomer', 'perhaps', 'refuge', 'suggestion', 'non', 'luminosity', 'here', 'analogy', 'suddenly', 'let', 'fall', 'surcingle', 'hung', 'ribands', 'body', 'knew', 'you', 'could', 'say', 'yourself', 'stereotomy', 'brought', 'think', 'atomies', 'thus', 'theories', 'epicurus', 'since', 'discussed', 'subject', 'very', 'long', 'ago', 'mentioned', 'singularly', 'yet', 'little', 'notice', 'vague', 'guesses', 'noble', 'greek', 'had', 'met', 'confirmation', 'late', 'nebular', 'cosmogony', 'avoid', 'casting', 'eyes', 'upward', 'great', 'nebula', 'orion', 'certainly', 'expected', 'would', 'do', 'confess', 'neither', 'structure', 'languages', 'nor', 'code', 'governments', 'politics', 'various', 'states', 'possessed', 'attractions', 'shall', 'find', 'can', 'feel', 'injuries', 'learn', 'dread', 'revenge', 'few', 'days', 'after', 'arrived', 'barricaded', 'ourselves', 'present', 'were', 'herbert', 'west', 'needed', 'fresh', 'bodies', 'because', 'life', 'work', 'reanimation', 'dead', 'farm', 'like', 'grounds', 'extended', 'back', 'deeply', 'up', 'almost', 'wheaton', 'street', 'glance', 'will', 'show', 'fallacy', 'idea', 'escaped', 'must', 'commence', 'destructive', 'endless', 'journey', 'across', 'mountainous', 'ices', 'ocean', 'amidst', 'cold', 'inhabitants', 'endure', 'native', 'genial', 'sunny', 'climate', 'hope', 'survive', 'these', 'speeches', 'they', 'gave', 'course', 'their', 'own', 'interpretation', 'fancying', 'doubt', 'events', 'should', 'come', 'into', 'possession', 'vast', 'quantities', 'ready', 'money', 'provided', 'them', 'owed', 'trifle', 'more', 'consideration', 'dare', 'cared', 'what', 'became', 'either', 'soul', 'or', 'carcass', 'her', 'sprightliness', 'undue', 'excitement', 'placid', 'reposed', 'contented', 'love', 'well', 'children', 'beauty', 'surrounding', 'nature', 'went', 'far', 'speak', 'slightly', 'hectic', 'cough', 'one', 'time', 'been', 'troubled', 'chronic', 'rheumatism', 'twinge', 'hereditary', 'gout', 'conclusion', 'disagreeable', 'inconvenient', 'hitherto', 'carefully', 'concealed', 'weakness', 'facial', 'aspect', 'too', 'remarkable', 'maturity', 'though', 'shared', 'mothers', 'grandfathers', 'chinlessness', 'firm', 'precociously', 'shaped', 'nose', 'united', 'expression', 'large', 'dark', 'latin', 'give', 'quasi', 'adulthood', 'nigh', 'preternatural', 'intelligence', 'now', 'net', 'permanently', 'fastened', 'hoop', 'attached', 'series', 'running', 'loops', 'nooses', 'sounds', 'hideous', ...
# [-0.20790239 -0.07794965 -0.0858935   0.24942276  0.18815392 -0.26150584
#   0.06359302 -0.00752349  0.0634217  -0.15334362 -0.1061916   0.03069662
#   0.15432717  0.15713477  0.09752591 -0.19432446  0.09035399 -0.11006512
#   0.00500547  0.03520728 -0.08242594 -0.3844125  -0.03298572 -0.19981718
#   0.20002717 -0.05754993  0.08953391  0.10257492 -0.11503956  0.09740441
#   0.11339311  0.04587987 -0.28254178  0.06144304  0.14804819 -0.04465448
#   0.36921602  0.180273   -0.03999977  0.08049192 -0.17499332 -0.03409747
#  -0.25021404  0.08175026 -0.02458115 -0.24643077 -0.03020445 -0.23483409
#  -0.14847618 -0.07369862 -0.28570566 -0.28651026 -0.18386433 -0.08795654
#   0.04736024 -0.00633862  0.09653094 -0.06468241 -0.10340571  0.10484264
#   0.07628588 -0.25338784 -0.3476185   0.04166662 -0.03839712  0.07103358
#  -0.07330526  0.01089578 -0.08843137  0.23551284  0.11779626  0.1921087
#   0.00906043 -0.02167328 -0.22433773  0.07477944  0.15678263  0.0348484
#  -0.22758813  0.12946135 -0.05414525  0.005507    0.00697233 -0.00655034
#   0.07061526 -0.08033656  0.09292398 -0.02221661  0.0325526   0.16071084
#   0.10333727 -0.28193045  0.17615587  0.10457237 -0.08543901  0.04219401
#  -0.07001417  0.25973797  0.21488291 -0.24291684]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Word2Vec(vocab=25766, size=100, alpha=0.025)
# ['somehow', 'cocacola', 'has', 'a', 'way', 'of', 'summing', 'up', 'things', 'so', 'well', 'in', 'the', 'early', '1970s', 'they', 'had', 'as', 'their', 'flagship', 'jingle', 'id', 'like', 'to', 'buy', 'world', 'coke', 'tune', 'teach', 'sing', 'that', 'pretty', 'much', 'summed', 'postwoodstock', 'era', 'it', 'didnt', 'add', 'sales', 'but', 'was', 'catchy', 'korea', 'cokes', 'theme', 'is', 'stop', 'thinking', 'which', 'sums', 'lot', 'about', 'and', 'koreans', 'look', 'at', 'how', 'relaxed', 'couple', 'now', 'stopped', 'started', 'feeling', 'course', 'have', 'high', 'regard', 'for', 'education', 'math', 'logic', 'such', 'deep', 'down', 'i', 'think', 'many', 'really', 'work', 'on', 'emotion', 'more', 'than', 'anything', 'else', 'westerners', 'seem', 'sublimate', 'this', 'moreso', 'or', 'least', 'display', 'different', 'are', 'probably', 'similar', 'context', 'we', 'do', 'anyways', 'if', 'you', 'youre', 'losing', 'just', 'repeat', 'yourself', 'feel', 'everything', 'will', 'be', 'alright', 'country', 'extremes', 'may', 'come', 'from', 'koreas', 'history', 'been', 'invaded', 'reported', '700', 'times', 'over', 'years', 'each', 'time', 'got', 'independence', 'imagine', 'move', 'quickly', 'get', 'next', 'level', 'before', 'war', 'occupation', 'lately', 'not', '1945', 'japanese', 'ended', 'then', 'korean', 'occurred', '19503', 'after', 'there', 'turmoil', '1961', 'park', 'chung', 'hee', 'took', 'dictatorpresident', 'he', 'elections', 'everyone', 'encouraged', 'vote', 'still', 'dictator', 'his', 'assassination', '1979', 'few', 'leaders', 'were', 'basically', 'same', 'ilk', 'president', 'did', 'some', 'amazing', 'however', 'an', 'incredibly', 'backward', 'set', 'road', 'industrialization', 'japan', 'stripped', 'its', 'resources', 'people', 'even', 'language', 'culture', 'buildings', 'palaces', 'razed', 'official', 'here', '19101945', 'determined', 'change', 'orchestrated', 'han', 'river', 'miracle', 'hangang', 'main', 'seoulkorea', 'made', 'terrific', 'strides', 'expense', 'civil', 'liberties', 'fastforward', 'present', 'my', 'point', 'see', 'worlds', '1', 'wired', 'nation', 'canada', 'finland', 'beyond', 'u', 'craze', 'pcs', 'pc', 'bangs', 'rooms', 'everywhere', 'instead', 'playstationlike', 'games', 'where', 'players', 'go', 'against', 'computer', 'one', 'two', 'gamers', 'always', 'communal', 'types', 'play', 'online', 'with', 'hundreds', 'thousands', 'others', 'typical', 'fashion', 'who', 'left', 'seat', 'second', 'could', 'pause', 'game', 'fact', 'eliminated', 'pcbang', 'owners', 'sold', 'drinks', 'ramen', 'nooodles', 'other', 'junk', 'clientele', 'matter', 'someone', 'died', 'related', 'article', 'yes', 'being', 'thought', 'sleeping', 'long', 'checked', 'him', 'out', 'alas', 'first', 'known', 'casulty', 'net', 'maybe', 'built', 'both', 'good', 'bad', 'take', 'read', 'news', 'joongang', 'ilbo', 'north', 'opinion', 'scaling', 'troops', 'seoul', 'specifically', '3600', 'heading', 'iraq', 'by', 'end', '2005', 'current', 'total', '37000', 'should', 'drop', '24500', 'troop', 'cuts', 'again', 'blasted', 'united', 'states', 'yesterday', 'what', 'calls', 'increase', 'defense', 'capabilities', 'planned', 'relocation', 'south', 'pyeongyangs', 'staterun', 'television', 'network', 'said', 'plans', 'preparations', 'though', 'part', 'ground', 'forces', 'transferred', 'causing', 'capability', 'vacuum', 'bush', 'augmenting', 'policy', 'broadcast', 'complained', 'security', 'commitment', 'preemptive', 'us', 'affairs', 'commentary', 'ok', 'let', 'me', 'straight', 'moving', 'further', 'area', 'closest', 'dmz', 'demilitarized', 'zone', 'increasing', 'ive', 'propaganda', 'dprk', 'com', 'check', 'section', 'unreal', 'remind', 'those', 'tell', 'means', 'democratic', 'peoples', 'republic', 'very', 'leadership', 'seems', 'making', 'all', 'waves', 'wrong', 'im', 'going', 'find', 'brutal', 'event', 'severed', 'families', 'whom', 'lucky', 'enough', 'aged', 'relatives', 'remember', '50', 'special', 'reunion', 'projects', 'albeit', 'only', 'hours', 'whisked', 'off' ...
# [-9.87268463e-02 -1.30258305e-02 -4.88013551e-02  1.11482538e-01
#   1.09895624e-01 -2.33736429e-02  1.04882658e-01 -6.38480112e-02
#   6.06323853e-02 -4.82324623e-02 -8.99832547e-02 -8.08920804e-03
#   1.24458559e-01  3.83824669e-02  1.06977450e-03 -6.10555410e-02
#   4.53955606e-02  1.29811289e-02 -4.94547188e-03 -5.28956912e-02
#   2.91895699e-02 -1.77534923e-01  2.12009475e-02 -4.87906374e-02
#   1.17344476e-01  7.21860081e-02  9.58268810e-03 -1.41640520e-02
#  -6.23319484e-03  2.46296320e-02  1.24053642e-01 -4.25055698e-02
#  -1.55548260e-01  1.13289990e-01  1.10037804e-01  6.54842937e-03
#   1.97738901e-01  1.49278969e-01 -5.39086014e-02 -4.75557847e-03
#  -5.84931374e-02  1.35839600e-02 -7.98395276e-02  1.29678935e-01
#  -2.70663351e-02 -3.53944302e-02 -8.24984536e-02 -1.92160442e-01
#  -5.54233380e-02 -9.58957069e-04 -5.54582365e-02 -1.43433452e-01
#  -1.05838971e-02 -4.25138846e-02 -4.48312387e-02  2.29658112e-02
#  -1.13227986e-01  7.45910406e-02  8.47511645e-03  1.03917189e-01
#   2.05353741e-02 -6.49362803e-02 -2.07435831e-01 -1.14755332e-02
#  -5.79352677e-02  2.10489668e-02 -5.62199615e-02  3.36741880e-02
#  -3.62473466e-02  9.96871677e-05  5.19693792e-02  1.40699953e-01
#  -2.37243399e-02 -2.07807515e-02 -5.91194816e-02 -1.89122241e-02
#   6.45865276e-02  2.75318865e-02 -8.52595791e-02  2.21385323e-02
#   3.60856801e-02  2.50016246e-02  1.27790824e-01 -1.15541955e-02
#  -1.07178353e-02  2.77137775e-02  1.18629476e-02  6.69057220e-02
#   3.79697187e-03  7.15393748e-04 -1.14779444e-02 -1.27424821e-01
#   1.25021756e-01  9.29643139e-02 -1.26614243e-01  4.36847769e-02
#   2.46746223e-02  1.53148875e-01  8.67867246e-02 -1.82083771e-01]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:96: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
#
#
# Brownlee, Jason. “How to Develop Word Embeddings in Python with Gensim.” Machine Learning Mastery, 7 Aug. 2019, machinelearningmastery.com/develop-word-embeddings-python-gensim/.

# %% [markdown]
# Section 3: Evaluate the differences between the word embeddings
# ----------------------------
#
# (make sure to include graphs, figures, and paragraphs with full sentences)

# %%
# -----------------Section 3: Evaluate the differences between the word embeddings-------------------
#This section is evaluating via PCAs
primaryModel = model_primaryDataset[model_primaryDataset.wv.vocab]
secondaryModel = model_secondaryDataset[model_secondaryDataset.wv.vocab]
#Retirives the vectors from each embedding

pcaP = PCA(n_components=2)
resultP = pcaP.fit_transform(primaryModel)
plt.scatter(resultP[:, 0], resultP[:, 1], s=5, color='teal')
words_primaryDataset = list(model_primaryDataset.wv.vocab)
plt.title('Two-Dimensional PCA for the Primary Data Set')
plt.xlabel('Variable B')
plt.ylabel('Variable A')
plt.show()
#PCA model for the primary dataset

pcaS = PCA(n_components=2)
resultS = pcaS.fit_transform(secondaryModel)
plt.scatter(resultS[:, 0], resultS[:, 1], s=5, color='coral')
words_secondaryDataset = list(model_secondaryDataset.wv.vocab)
plt.title('Two-Dimensional PCA for the Secondary Data Set')
plt.xlabel('Variable B')
plt.ylabel('Variable A')
plt.show()
#PCA model for the secondary dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-85dad43ed8a0> in <module>
#       1 # -----------------Section 3: Evaluate the differences between the word embeddings-------------------
#       2 #This section is evaluating via PCAs
# ----> 3 primaryModel = model_primaryDataset[model_primaryDataset.wv.vocab]
#       4 secondaryModel = model_secondaryDataset[model_secondaryDataset.wv.vocab]
#       5 #Retirives the vectors from each embedding
#
# NameError: name 'model_primaryDataset' is not defined

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
# Brownlee, Jason. “How to Develop Word Embeddings in Python with Gensim.” Machine Learning Mastery, 7 Aug. 2019, machinelearningmastery.com/develop-word-embeddings-python-gensim/. <br>
# Durksen, Luuk. "Visualising high-dimensional datasets using PCA and t-SNE in Python" 29 Oct. 2016, https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %% [markdown]
# Section 4: Feedforward Neural Language Model
# --------------------------

# %%
# code to train a feedforward neural language model
# on a set of given word embeddings
# make sure not to just copy + paste to train your two

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 5: Recurrent Neural Language Model
# --------------------------

# %%
# code to train a recurrent neural language model 
# on a set of given word embeddings
# make sure not to just copy + paste to train your two

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 6: Evaluate the differences between the two language models
# ----------------------------
#
# (make sure to include graphs, figures, and paragraphs with full sentences)

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
