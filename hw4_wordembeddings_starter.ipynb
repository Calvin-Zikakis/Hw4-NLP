# %% [markdown]
# For this homework, make sure that you format your notbook nicely and cite all sources in the appropriate sections. Programmatically generate or embed any figures or graphs that you need.
#
# Names: Calvin Zikakis, Sarah Schwallier

# %% [markdown]
# Section 1: Word2Vec paper questions
# ---------------------------
#
#     1) Describe how a CBOW word embedding is generated.
#
#     2) What is a CBOW word embedding and how is it different than a skip-gram word embedding?
#
#     3) What is the task that the authors use to evaluate the generated word embeddings?
#
#     4) What are PCA and t-SNE? Why are these important to the task of training and interpreting word embeddings?

# %% [markdown]
# Sources Cited
# --------------------------
# Efficient Estimation of Word Representations in Vector Space by Tomas Mikolov, Kai Chen, Greg Corrado, and Jeffrey Dean: https://arxiv.org/pdf/1301.3781.pdf
# J. Schler, M. Koppel, S. Argamon and J. Pennebaker (2006). Effects of Age and Gender on Blogging in Proceedings of 2006 AAAI Spring Symposium on Computational Approaches for Analyzing Weblogs.
# SENTENCE ORDERING USING RECURRENT NEURAL NETWORKS by Lajanugen Logeswaran, Honglak Lee & Dragomir Radev
# Speech and Language Processing
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 2: Training your own word embeddings
# --------------------------------
#
# The spooky authors dataset consists of excerpts from authors of horror novels including Edgar Allan Poe, Mary Shelley, and HP Lovecraft. These excerpts each have a unique ID as well as a three letter tag describing which author wrote the excerpt. The data is split into a training set and a test set. The test set is lacking the three letter code which labels the author.
#
#
# We are using the The Blog Authorship Corpus for our secondary dataset. We decided on this dataset as it is comprised of 681,288 posts from 19,320 bloggers. We scanned through this database and pulled a small chunk of the total amount of posts. This was to reduce the overall size of the dataset to help with performance in training word embedding. This dataset will provide a data that is written with a style simular to normal human conversation simularly to the spooky authors dataset. This should help insure our generated sentences have a natural sound to them.

# %%
# import your libraries here
import numpy as np
import sklearn
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import keras
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, Embedding, Flatten
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical




import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns
import csv


# %matplotlib inline

# %%
# -----------------Secondary Dataset Formatting and Trimming-------------------
# This cell trims and fixes the secondary dataset to get the data in a workable style
import re
from csv import reader


def format_secondaryDataset(training_file_path, output_file, sentence_length):
    '''
    this function takes the dataset and splits it to sentences and stores those in a txt file

    training_file_path = filepath of blogposts.csv
    output_file = outputfile name (.txt)
    sentence_length = minimum length sentences to grab (value is how many words per sentences)
    '''

    
    with open(training_file_path) as file:
        sentences = file.readlines()
    #open file
    
    file.close()
    
    output = open(output_file, "w+")
    
    count = 0
    
    for line in reader(sentences):
        blog_post = line[6]
        #Line[6] contains the blog post
        
        if count >= 7:
        #skip the stuff in the beggining. It's unneeded
        
            sentences = blog_post.split(".")
            #split the post on the periods to extract individual sentences
            
            for sentence in sentences:
            #loop over our list of sentences
            
                if sentence != "":
                #some blog posts contain '...'. This creates empty sentences. We don't want empty sentences
                    
                    #lets clean the sentence of symbols and make it all lowercase
                    
                    res = re.sub(' +', ' ', sentence)
                    res.strip('\t')
                    res.strip('\n')
                    #strip tabs and newlines
                    
                    lower = res.lower()
                    #make all lower case

                    whitelist = set('abcdefghijklmnopqrstuvwxyz 1234567890')
                    no_numbers_punct = ''.join(filter(whitelist.__contains__, lower))
                    #gets rid of punctuation

                    cleaned = no_numbers_punct.split()
                    
                    black_list = ['urllink']
                    #allows us to remove all 'urlLink' occurances
                    
                    if len(cleaned) >= sentence_length:
                        #adjust 4 if you only want longer sentences
                        #we are only concerned with sentences longer than 4 words
                        output.write(" ".join([i for i in cleaned if i not in black_list]) + "\n")
                    
                    
        if count == 2000:
        #Do not need this full dataset... It's 800mb's
            break
        
        count += 1
        

format_secondaryDataset("blogtext.csv", "secondaryDataset.txt", 5)

# %%
# code to train your word embeddings
from csv import reader
from gensim.models import Word2Vec

EMB = 300



# -----------------Primary Dataset-------------------
def Clean_data_primary_dataset(training_file_path):
    #This function tokenizes the primary dataset and returns a cleaned version where each word making up a sentence is a nested list inside a larger list of the corpus
    output_list = []

    with open(training_file_path) as file:
        sentences = file.readlines()
    #open file
    file.close()
    
    count = 0
        
    for line in reader(sentences):
        
        if count != 0:
        #don't want first sentence

            sentence = line[1]
            
            lower = sentence.lower()
            #make all lower case

            whitelist = set('abcdefghijklmnopqrstuvwxyz 1234567890')
            no_numbers_punct = ''.join(filter(whitelist.__contains__, lower))
            #gets rid of punctuation

            cleaned = no_numbers_punct.split()
            
            output_list.append(cleaned)
            
        count += 1

    return output_list

    
sentences_primaryDataset = Clean_data_primary_dataset("train.csv")
#imports and cleans dataset

model_primaryDataset = Word2Vec(sentences_primaryDataset, min_count=5, size=EMB, window=4, negative=10, iter=10, workers=4)
#creates word2vec model

print(model_primaryDataset)
#model summary

words_primaryDataset = list(model_primaryDataset.wv.vocab)
print(words_primaryDataset)
#shows the vocab

print(model_primaryDataset['sentence'])
#our model

# -----------------Secondary Dataset-------------------

#secondary dataset is stored as 'secondaryDataset.txt' after processing it

def tokenize_secondary_dataset(training_file_path):
    #tokenizes the secondary dataset and returns a cleaned version where each word making up a sentence is a nested list inside a larger list of the corpus
    
    output_list = []

    with open(training_file_path) as file:
        sentences = file.readlines()
        
    #open file
    file.close()
    
    for sentence in sentences:
    #loop over sentences
    
        words = sentence.split()
        #split sentences on the words
        
        output_list.append(words)
        #append words list to final output
    
    return output_list


sentences_secondaryDataset = tokenize_secondary_dataset("secondaryDataset.txt")
#secondary sentences

model_secondaryDataset = Word2Vec(sentences_secondaryDataset, min_count=5, size=EMB, window=4, negative=10, iter=10, workers=4)
#creates word2vec model

print(model_secondaryDataset)
#model summary

words_secondaryDataset = list(model_secondaryDataset.wv.vocab)
print(words_secondaryDataset)
#shows the vocab

print(model_secondaryDataset['sentence'])
#our model
# Out:
# Word2Vec(vocab=8521, size=300, alpha=0.025)
# ['this', 'process', 'however', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the', 'dimensions', 'my', 'dungeon', 'as', 'i', 'might', 'make', 'its', 'circuit', 'and', 'return', 'to', 'point', 'whence', 'set', 'out', 'without', 'being', 'aware', 'fact', 'so', 'perfectly', 'uniform', 'seemed', 'wall', 'it', 'never', 'once', 'occurred', 'that', 'fumbling', 'be', 'a', 'mere', 'mistake', 'in', 'his', 'left', 'hand', 'was', 'gold', 'snuff', 'box', 'from', 'which', 'he', 'down', 'hill', 'cutting', 'all', 'manner', 'fantastic', 'steps', 'took', 'incessantly', 'with', 'an', 'air', 'greatest', 'possible', 'self', 'satisfaction', 'how', 'lovely', 'is', 'spring', 'we', 'looked', 'windsor', 'terrace', 'on', 'sixteen', 'fertile', 'spread', 'beneath', 'by', 'happy', 'cottages', 'towns', 'former', 'years', 'heart', 'fair', 'finding', 'nothing', 'else', 'not', 'even', 'superintendent', 'abandoned', 'attempts', 'but', 'perplexed', 'look', 'occasionally', 'over', 'countenance', 'sits', 'thinking', 'at', 'desk', 'youth', 'passed', 'solitude', 'best', 'spent', 'under', 'your', 'gentle', 'feminine', 'has', 'refined', 'character', 'cannot', 'overcome', 'intense', 'distaste', 'usual', 'exercised', 'board', 'ship', 'have', 'believed', 'necessary', 'when', 'heard', 'equally', 'noted', 'for', 'respect', 'obedience', 'paid', 'him', 'crew', 'felt', 'myself', 'peculiarly', 'fortunate', 'able', 'secure', 'services', 'perhaps', 'refuge', 'suggestion', 'non', 'luminosity', 'here', 'analogy', 'suddenly', 'let', 'fall', 'hung', 'body', 'knew', 'you', 'could', 'say', 'yourself', 'brought', 'think', 'thus', 'theories', 'since', 'discussed', 'subject', 'very', 'long', 'ago', 'mentioned', 'singularly', 'yet', 'little', 'notice', 'vague', 'guesses', 'noble', 'greek', 'had', 'met', 'confirmation', 'late', 'avoid', 'casting', 'eyes', 'upward', 'great', 'orion', 'certainly', 'expected', 'would', 'do', 'confess', 'neither', 'structure', 'languages', 'nor', 'code', 'various', 'states', 'possessed', 'attractions', 'shall', 'find', 'can', 'feel', 'injuries', 'learn', 'dread', 'revenge', 'few', 'days', 'after', 'arrived', 'ourselves', 'present', 'were', 'herbert', 'west', 'needed', 'fresh', 'bodies', 'because', 'life', 'work', 'reanimation', 'dead', 'like', 'grounds', 'extended', 'back', 'deeply', 'up', 'almost', 'street', 'glance', 'will', 'show', 'idea', 'escaped', 'must', 'commence', 'destructive', 'endless', 'journey', 'across', 'mountainous', 'ocean', 'amidst', 'cold', 'inhabitants', 'endure', 'native', 'genial', 'sunny', 'climate', 'hope', 'survive', 'these', 'speeches', 'they', 'gave', 'course', 'their', 'own', 'interpretation', 'fancying', 'doubt', 'events', 'should', 'come', 'into', 'possession', 'vast', 'ready', 'money', 'provided', 'them', 'owed', 'trifle', 'more', 'consideration', 'dare', 'what', 'became', 'either', 'soul', 'or', 'her', 'undue', 'excitement', 'placid', 'reposed', 'contented', 'love', 'well', 'children', 'beauty', 'surrounding', 'nature', 'went', 'far', 'speak', 'slightly', 'hectic', 'cough', 'one', 'time', 'been', 'troubled', 'hereditary',
#  -7.68238604e-02  5.51631823e-02 -2.74368852e-01  3.24886180e-02
#  -6.42850623e-02 -2.15214342e-01 -5.99455088e-02 -5.28576262e-02
#  -2.18456984e-02 -1.00121640e-01 -8.92478973e-02 -1.11573949e-01
#   1.28101200e-01  1.15957886e-01  1.50380462e-01  1.80921987e-01
#  -1.59154758e-01 -1.88913375e-01 -1.53027708e-03  5.87656163e-02
#  -5.39496318e-02  9.11380798e-02  1.78644747e-01 -8.91337842e-02
#   1.70379996e-01 -1.38661250e-01  1.06527597e-01  1.72558978e-01
#   2.54737467e-01  1.02966100e-01  8.73485655e-02  8.84398818e-02
#   1.24258414e-01  1.04814582e-01  8.41453075e-02  3.53527725e-01
#   1.40489057e-01  8.05273280e-02  2.09831893e-02  1.08839512e-01
#   1.26762450e-01  2.39039329e-03  1.52250409e-01 -2.37816215e-01
#   2.49253973e-01 -1.40047997e-01 -4.24122345e-03 -6.04973137e-02]
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Word2Vec(vocab=5587, size=300, alpha=0.025)
# ['somehow', 'has', 'a', 'way', 'of', 'up', 'things', 'so', 'well', 'in', 'the', 'early', 'they', 'had', 'as', 'their', 'id', 'like', 'to', 'buy', 'world', 'coke', 'tune', 'teach', 'sing', 'that', 'pretty', 'much', 'era', 'it', 'didnt', 'add', 'sales', 'but', 'was', 'korea', 'theme', 'is', 'stop', 'thinking', 'which', 'lot', 'about', 'and', 'koreans', 'look', 'at', 'how', 'relaxed', 'couple', 'now', 'stopped', 'started', 'feeling', 'course', 'have', 'high', 'regard', 'for', 'education', 'math', 'logic', 'such', 'deep', 'down', 'i', 'think', 'many', 'really', 'work', 'on', 'emotion', 'more', 'than', 'anything', 'else', 'seem', 'this', 'or', 'least', 'display', 'different', 'are', 'probably', 'similar', 'context', 'we', 'do', 'anyways', 'if', 'you', 'youre', 'losing', 'just', 'repeat', 'yourself', 'feel', 'everything', 'will', 'be', 'alright', 'country', 'may', 'come', 'from', 'koreas', 'history', 'been', 'reported', 'times', 'over', 'years', 'each', 'time', 'got', 'independence', 'imagine', 'move', 'quickly', 'get', 'next', 'level', 'before', 'war', 'lately', 'not', 'japanese', 'ended', 'then', 'korean', 'occurred', 'after', 'there', 'turmoil', 'park', 'chung', 'hee', 'took', 'he', 'elections', 'everyone', 'vote', 'still', 'dictator', 'his', 'few', 'leaders', 'were', 'basically', 'same', 'president', 'did', 'some', 'amazing', 'however', 'an', 'incredibly', 'set', 'road', 'japan', 'stripped', 'its', 'resources', 'people', 'even', 'language', 'culture', 'buildings', 'official', 'here', 'determined', 'change', 'han', 'river', 'miracle', 'main', 'made', 'civil', 'liberties', 'present', 'my', 'point', 'see', 'worlds', '1', 'nation', 'canada', 'beyond', 'u', 'pc', 'rooms', 'everywhere', 'instead', 'games', 'where', 'players', 'go', 'against', 'computer', 'one', 'two', 'always', 'types', 'play', 'online', 'with', 'hundreds', 'thousands', 'others', 'typical', 'fashion', 'who', 'left', 'seat', 'second', 'could', 'game', 'fact', 'eliminated', 'sold', 'drinks', 'other', 'junk', 'matter', 'someone', 'died', 'related', 'article', 'yes', 'being', 'thought', 'sleeping', 'long', 'checked', 'him', 'out', 'alas', 'first', 'known', 'net', 'maybe', 'built', 'both', 'good', 'bad', 'take', 'read', 'news', 'joongang', 'ilbo', 'north', 'opinion', 'troops', 'seoul', 'specifically', 'heading', 'iraq', 'by', 'end', '2005', 'current', 'total', 'should', 'drop', 'cuts', 'again', 'united', 'states', 'yesterday', 'what', 'calls', 'increase', 'defense', 'capabilities', 'planned', 'south', 'television', 'network', 'said', 'plans', 'though', 'part', 'ground', 'forces', 'causing', 'capability', 'bush', 'policy', 'complained', 'security', 'commitment', 'us', 'commentary', 'ok', 'let', 'me', 'straight', 'moving', 'further', 'area', 'closest', 'zone', 'ive', 'propaganda', 'com', 'check', 'section', 'remind', 'those', 'tell', 'means', 'democratic', 'peoples', 'republic', 'very', 'seems', 'making', 'all', 'waves', 'wrong', 'im', 'going', 'find', 'brutal', 'event', 'families', 'whom', 'lucky', 'enough', 'relatives', 'remember', '50', 'special', 'reunion', 'projects', 'albeit', 'only', 'hours', 'off', 'respective', 'countries', 'pass', 'without', 'ever', 'seeing', 'sister', 'brother', 'child', 'parent', 'west', 'especially', 'weve', 'never', 'our', 'own', 'except', 'fully', 'makes', 'your', 'wonder', 'far', 'would', 'support', 'guess', 'idea', 'surf', 'english', 'sites', 'looking', 'foreigners', 'view', 'kingdom', 'also', 'keep', 'place', 'sometimes', 'needs', 'figures', 'put', 'papers', 'version', 'daily', 'arrested', 'says', 'accused', 'huh', 'another', 'sp', 'positive', 'banks', 'thing', 'while', 'worried', 'loans', 'extended', 'small', 'firms', 'no', 'why', 'simple', 'facts', 'presented', 'differently', 'cant', 'simply', 'can', 'looks', 'difficult', 'figure', 'surprisingly', '24', 'characters', 'easy', 'sentence', 'structure', 'luckily', 'options', 'list', 'them', 'guy', 'motivation', 'latest', 'actually', 'star', 'movies', 'hear', 'commercial', 'feature', 'saw', 'h ...
# [ 5.24474680e-02  1.62796885e-01  4.16393839e-02  4.76931036e-02
#   4.79002558e-02  2.39018984e-02  2.43911713e-01 -2.39966009e-02
#   1.27922073e-02 -2.89210621e-02  8.49158689e-02  2.65482981e-02
#   4.94262017e-03  6.21533953e-02  4.52993922e-02  1.94935769e-01
#  -1.14507182e-02  1.88508872e-02 -8.45244229e-02  2.93314196e-02
#   7.88981318e-02 -1.48478374e-01  6.50609061e-02  2.74689317e-01
#   9.27874669e-02  1.82865150e-02  4.51327451e-02 -3.66810672e-02
#   3.19451541e-02  1.14333965e-01 -3.99153382e-02  1.51518956e-01
#  -1.07399166e-01 -1.97293926e-02 -6.68986049e-03 -5.11881262e-02
#   5.66885583e-02 -1.52746767e-01 -4.96697612e-02  7.78473467e-02
#   1.74537510e-01 -2.89934315e-02 -1.20934963e-01  6.27202615e-02
#  -1.74111351e-02  9.09929723e-02  1.15779743e-01 -9.85248713e-04
#   8.75299498e-02 -1.72539968e-02 -1.30188406e-01  5.53983971e-02
#  -8.65568891e-02  1.94326378e-02  1.86473187e-02 -2.42277771e-01
#   1.40455559e-01 -6.31304234e-02  2.39457190e-02 -2.04422418e-03
#  -8.44249725e-02 -1.46765441e-01 -2.03695476e-01 -1.25440344e-01
#  -1.46142587e-01 -1.03025539e-02 -4.40933257e-02 -1.46948462e-02
#  -1.48370311e-01  3.02059166e-02 -7.68057704e-02  1.04111031e-01
#   1.28967464e-01 -9.95712504e-02  5.27414642e-02  5.10239713e-02
#   2.85942741e-02  8.94325152e-02  1.41670734e-01  4.67880964e-02
#  -7.03869760e-02 -1.00476004e-01 -1.47507161e-01 -5.38280904e-02
#  -2.89928705e-01 -6.59698546e-02  9.17707831e-02 -7.77269006e-02
#  -1.04273818e-02  1.90676916e-02  1.12083048e-01 -9.25963074e-02
#  -4.33325674e-03 -5.40103130e-02 -7.15973601e-02 -1.13431677e-01
#   1.53633207e-01  3.17700878e-02  1.78387761e-01  9.88509580e-02
#  -3.19799930e-02  8.51191208e-02  1.61678731e-01  5.04199639e-02
#  -8.14945847e-02 -7.13443104e-03 -1.86615661e-01  2.91654710e-02
#  -1.76369697e-01 -6.39524013e-02  5.94692267e-02  3.25073488e-02
#  -5.50526083e-02  2.77236458e-02  2.34305412e-02  4.85436693e-02
#   6.77784383e-02  7.45597109e-02  1.90068200e-01  4.52148542e-02
#  -5.26033379e-02 -1.44989908e-01 -8.71645883e-02 -6.77820668e-02
#  -2.90176142e-02 -1.67297851e-02  2.25852713e-01  3.81188206e-02
#   1.53788313e-01 -2.30169460e-01  4.68729995e-02  6.24129511e-02
#  -1.88773811e-01 -1.67925414e-02  2.44042873e-02 -4.94895922e-03
#   9.65025201e-02  1.45805523e-01 -6.59517199e-02  1.54604644e-01
#   4.92103994e-02  5.88898100e-02  3.56946997e-02  6.37564436e-03
#   6.46514595e-02 -3.20103136e-05  1.63465634e-01 -2.14022443e-01
#   1.28011584e-01 -7.97880888e-02 -8.42669085e-02 -8.35134163e-02]
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
#
#
# Brownlee, Jason. “How to Develop Word Embeddings in Python with Gensim.” Machine Learning Mastery, 7 Aug. 2019, machinelearningmastery.com/develop-word-embeddings-python-gensim/.

# %% [markdown]
# Section 3: Evaluate the differences between the word embeddings
# ----------------------------
#
# (make sure to include graphs, figures, and paragraphs with full sentences)

# %%
# -----------------Section 3: Evaluate the differences between the word embeddings-------------------
#This section is evaluating via PCAs
primaryModel = model_primaryDataset[model_primaryDataset.wv.vocab]
secondaryModel = model_secondaryDataset[model_secondaryDataset.wv.vocab]
#Retirives the vectors from each embedding

pcaP = PCA(n_components=2)
resultP = pcaP.fit_transform(primaryModel)
plt.scatter(resultP[:, 0], resultP[:, 1], s=5, color='teal')
words_primaryDataset = list(model_primaryDataset.wv.vocab)
plt.title('Two-Dimensional PCA for the Primary Data Set')
plt.xlabel('Variable B')
plt.ylabel('Variable A')
plt.show()
#PCA model for the primary dataset

pcaS = PCA(n_components=2)
resultS = pcaS.fit_transform(secondaryModel)
plt.scatter(resultS[:, 0], resultS[:, 1], s=5, color='coral')
words_secondaryDataset = list(model_secondaryDataset.wv.vocab)
plt.title('Two-Dimensional PCA for the Secondary Data Set')
plt.xlabel('Variable B')
plt.ylabel('Variable A')
plt.show()
#PCA model for the secondary dataset
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
# Brownlee, Jason. “How to Develop Word Embeddings in Python with Gensim.” Machine Learning Mastery, 7 Aug. 2019, machinelearningmastery.com/develop-word-embeddings-python-gensim/. <br>
# Durksen, Luuk. "Visualising high-dimensional datasets using PCA and t-SNE in Python" 29 Oct. 2016, https://towardsdatascience.com/visualising-high-dimensional-datasets-using-pca-and-t-sne-in-python-8ef87e7915b

# %% [markdown]
# Section 4: Feedforward Neural Language Model
# --------------------------

# %%
# code to train a feedforward neural language model
# on a set of given word embeddings
# make sure not to just copy + paste to train your two

vec = 300

def convert_data(data):
#flattens data to 1D matrix
    data_flattened = []
    
    for sentences in data:
        for word in sentences:
            data_flattened.append(word)
    
    return data_flattened


def data_to_index(data, model):
#assigns index values to data
    data_index = []
    
    for word in data:
        if word in model:
            data_index.append(model.vocab[word].index)
            
    return data_index

#------------------ Primary Dataset -----------------

sentences_primaryFlattened = convert_data(sentences_primaryDataset)
index_data_primary = data_to_index(sentences_primaryFlattened,model_primaryDataset.wv)

print(sentences_primaryFlattened[:4],index_data_primary[:4])


#convert data to useable format for tensorflow / keras
embedding_primaryMatrix = np.zeros((len(model_primaryDataset.wv.vocab),EMB))

for i in range(len(model_primaryDataset.wv.vocab)):
    vector_primary = model_primaryDataset.wv[model_primaryDataset.wv.index2word[i]]
    
    if vector_primary is not None:
        embedding_primaryMatrix[i] = vector_primary
        


#------------------ Secondary Dataset -----------------

sentences_secondaryFlattened = convert_data(sentences_secondaryDataset)
index_data_secondary = data_to_index(sentences_secondaryFlattened,model_secondaryDataset.wv)

print(sentences_secondaryFlattened[:4],index_data_secondary[:4])


#convert data to useable format for tensorflow / keras
embedding_secondaryMatrix = np.zeros((len(model_secondaryDataset.wv.vocab),EMB))

for i in range(len(model_secondaryDataset.wv.vocab)):
    vector_secondary = model_secondaryDataset.wv[model_secondaryDataset.wv.index2word[i]]
    
    if vector_secondary is not None:
        embedding_secondaryMatrix[i] = vector_secondary
# Out:
# ['this', 'process', 'however', 'afforded'] [25, 2953, 142, 1372]
# ['somehow', 'cocacola', 'has', 'a'] [776, 76, 4, 98]

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 5: Recurrent Neural Language Model
# --------------------------

# %%
# code to train a recurrent neural language model 
# on a set of given word embeddings
# make sure not to just copy + paste to train your two

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin

# %% [markdown]
# Section 6: Evaluate the differences between the two language models
# ----------------------------
#
# (make sure to include graphs, figures, and paragraphs with full sentences)

# %% [markdown]
# Sources Cited
# --------------------------
# An Introduction to Natural Language Processing, Computational Linguistics, and Speech Recognition by Daniel Jurafsky and James H. Martin
